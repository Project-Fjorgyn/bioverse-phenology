# %%
import requests
import json
import pandas as pd
from datetime import datetime, timedelta
from tqdm import tqdm

# %%
def make_the_call(path, endpoint, **kwargs):
    url = f'http://www.usanpn.org/npn_portal/{path}/{endpoint}.json'
    if kwargs:
        query = '&'.join([f'{key}={value}' for key, value in kwargs.items()])
        url = f'{url}?{query}'
    return requests.request(
        url=url,
        method='GET'
    ).json()

make_the_call('species', 'getSpeciesById', species_id=1500)
# Out:
# {'common_name': 'pink trumpet-tree',
#  'genus': 'Tabebuia',
#  'species': 'rosea',
#  'kingdom': 'Plantae',
#  'itis_taxonomic_sn': 182287}

# %%
ma = pd.DataFrame(make_the_call('species', 'getSpeciesByState', state='MA'))
ma
# Out:
#      species_id             common_name        genus   kingdom       species  \
# 0          1436              absinthium    Artemisia   Plantae    absinthium
# 1          1227      Acadian flycatcher    Empidonax  Animalia     virescens
# 2           174                 alfalfa     Medicago   Plantae        sativa
# 3          1174  Allegheny serviceberry  Amelanchier   Plantae        laevis
# 4          1446   alternateleaf dogwood       Cornus   Plantae  alternifolia
# ..          ...                     ...          ...       ...           ...
# 672         154     yellow star-thistle    Centaurea   Plantae  solstitialis
# 673         175      yellow sweetclover    Melilotus   Plantae   officinalis
# 674        1675          yellow thistle      Cirsium   Plantae    horridulum
# 675         358          yellow warbler    Setophaga  Animalia      petechia
# 676        1097   yellow-rumped warbler    Setophaga  Animalia      coronata
#
#      itis_taxonomic_sn
# 0              35445.0
# 1             178339.0
# 2             183623.0
# 3             182046.0
# 4              27813.0
# ..                 ...
# 672            36972.0
# 673            26150.0
# 674            36379.0
# 675           950039.0
# 676           950046.0
#
# [677 rows x 6 columns]

# %%
ma[ma['genus'] == 'Juglans']
# Out:
#     species_id   common_name    genus  kingdom species  itis_taxonomic_sn
# 78          80  black walnut  Juglans  Plantae   nigra            19254.0

# %%
def get_pheno_df(species_id):
    return pd.DataFrame(
        make_the_call(
            'phenophases', 
            'getPhenophasesForSpecies', 
            **{'species_id[0]': species_id, 'date': '2020-01-01', 'return_all': True}
        )[0]['phenophases']
    )
phenos = get_pheno_df(80)
phenos
# Out:
# http://www.usanpn.org/npn_portal/phenophases/getPhenophasesForSpecies.json?species_id[0]=80&date=2020-01-01&return_all=True
#     phenophase_id            phenophase_name phenophase_category  \
# 0             371         Breaking leaf buds              Leaves
# 1             483                     Leaves              Leaves
# 2             467       Increasing leaf size              Leaves
# 3             498             Colored leaves              Leaves
# 4             471             Falling leaves              Leaves
# 5             500     Flowers or flower buds             Flowers
# 6             501               Open flowers             Flowers
# 7             502             Pollen release             Flowers
# 8             516                     Fruits              Fruits
# 9             390                Ripe fruits              Fruits
# 10            504  Recent fruit or seed drop              Fruits
#
#                                 phenophase_definition  \
# 0   One or more breaking leaf buds are visible on ...
# 1   One or more live, unfolded leaves are visible ...
# 2   A majority of leaves on the plant have not yet...
# 3   One or more leaves show some of their typical ...
# 4   One or more leaves are falling or have recentl...
# 5   One or more fresh open or unopened flowers or ...
# 6   One or more open, fresh flowers are visible on...
# 7   One or more flowers on the plant release visib...
# 8        One or more fruits are visible on the plant.
# 9   One or more ripe fruits are visible on the pla...
# 10  One or more mature fruits or seeds have droppe...
#
#                      phenophase_additional_definition  seq_num   color  \
# 0                                                           10  Green1
# 1                                                           30  Green1
# 2                                                           40  Green1
# 3                                                           70  Green1
# 4                                                          120  Green1
# 5   For Juglans nigra, the male inflorescence is a...      170  Green2
# 6   For Juglans nigra, the male flowers will open ...      190  Green2
# 7                                                          240  Green2
# 8   For Juglans nigra, the fruit is a nut covered ...      280  Green3
# 9   For Juglans nigra, a fruit is considered ripe ...      300  Green3
# 10                                                         330  Green3
#
#     pheno_class_id                 pheno_class_name  pheno_class_sequence  \
# 0                1     Initial shoot or leaf growth                    10
# 1                3                Leaves or needles                    30
# 2                2          Young leaves or needles                    20
# 3                4        Colored leaves or needles                    40
# 4                5        Falling leaves or needles                    50
# 5                6          Flowers or pollen cones                    60
# 6                7     Open flowers or pollen cones                    70
# 7                8                   Pollen release                    80
# 8               10             Fruits or seed cones                   100
# 9               12        Ripe fruits or seed cones                   120
# 10              13  Recent fruit, cone or seed drop                   130
#
#     abundance_category  raw_abundance
# 0                   39          False
# 1                   73          False
# 2                   41          False
# 3                   74          False
# 4                   -1          False
# 5                   48          False
# 6                   50          False
# 7                   51          False
# 8                   56          False
# 9                   58          False
# 10                  59          False

# %%
def get_obs_df(start, months, species_id):
    rows = []
    START = start
    MONTHS = months
    for month in range(MONTHS):
        start_date = datetime(
            START.year + (month + START.month - 1) // 12, 
            (START.month + month - 1) % 12 + 1,
            1
        )
        end_date = datetime(
            START.year + (month + START.month) // 12, 
            (START.month + month) % 12 + 1,
            1
        )
        form = '%Y-%m-%d'
        observations = make_the_call(
            'observations', 
            'getAllObservationsForSpecies', 
            **{'species_id[0]': species_id, 'start_date': start_date.strftime(form), 'end_date': end_date.strftime(form)}
        )
        for station in observations['station_list']:
            for pheno_id, counts in station['species'][str(species_id)].items():
                yes, no, q = counts.get('y', 0), counts.get('n', 0), counts.get('q', 0)
                rows.append({
                    'year': start_date.year,
                    'month': start_date.month,
                    'station_id': station['station_id'],
                    'phenophase_id': pheno_id,
                    'percent_yes': yes/(yes+no+q),
                })
    df = pd.DataFrame(rows)
    return df

df = get_obs_df(datetime(2019, 1, 1), 12, 80)
# Out:
# http://www.usanpn.org/npn_portal/observations/getAllObservationsForSpecies.json?species_id[0]=80&start_date=2019-01-01&end_date=2019-02-01
# http://www.usanpn.org/npn_portal/observations/getAllObservationsForSpecies.json?species_id[0]=80&start_date=2019-02-01&end_date=2019-03-01
# http://www.usanpn.org/npn_portal/observations/getAllObservationsForSpecies.json?species_id[0]=80&start_date=2019-03-01&end_date=2019-04-01
# http://www.usanpn.org/npn_portal/observations/getAllObservationsForSpecies.json?species_id[0]=80&start_date=2019-04-01&end_date=2019-05-01
# http://www.usanpn.org/npn_portal/observations/getAllObservationsForSpecies.json?species_id[0]=80&start_date=2019-05-01&end_date=2019-06-01
# http://www.usanpn.org/npn_portal/observations/getAllObservationsForSpecies.json?species_id[0]=80&start_date=2019-06-01&end_date=2019-07-01
# http://www.usanpn.org/npn_portal/observations/getAllObservationsForSpecies.json?species_id[0]=80&start_date=2019-07-01&end_date=2019-08-01
# http://www.usanpn.org/npn_portal/observations/getAllObservationsForSpecies.json?species_id[0]=80&start_date=2019-08-01&end_date=2019-09-01
# http://www.usanpn.org/npn_portal/observations/getAllObservationsForSpecies.json?species_id[0]=80&start_date=2019-09-01&end_date=2019-10-01
# http://www.usanpn.org/npn_portal/observations/getAllObservationsForSpecies.json?species_id[0]=80&start_date=2019-10-01&end_date=2019-11-01
# http://www.usanpn.org/npn_portal/observations/getAllObservationsForSpecies.json?species_id[0]=80&start_date=2019-11-01&end_date=2019-12-01
# http://www.usanpn.org/npn_portal/observations/getAllObservationsForSpecies.json?species_id[0]=80&start_date=2019-12-01&end_date=2020-01-01

# %%
def build_pheno_summary(obs_df, pheno_df):
    gdf = obs_df.groupby(['month', 'phenophase_id']).median()['percent_yes'].reset_index()
    gdf = gdf.merge(
        gdf.groupby('phenophase_id').max()['percent_yes'].reset_index().rename({'percent_yes': 'max_percent_yes'}, axis=1), 
        on='phenophase_id'
    )
    gdf = gdf[gdf['percent_yes'] == gdf['max_percent_yes']].groupby(
        ['phenophase_id', 'percent_yes']
    ).min()['month'].reset_index()
    gdf['phenophase_id'] = gdf['phenophase_id'].astype(int)
    gdf = gdf[gdf['percent_yes'] > 0]
    return gdf.merge(pheno_df[['phenophase_id', 'phenophase_name']], on=['phenophase_id']).sort_values('month')

build_pheno_summary(df, phenos)
# Out:
#    phenophase_id  percent_yes  month            phenophase_name
# 0            371     0.366667      4         Breaking leaf buds
# 2            467     0.833333      5       Increasing leaf size
# 4            483     1.000000      5                     Leaves
# 7            501     0.166667      5               Open flowers
# 6            500     0.200000      6     Flowers or flower buds
# 9            516     1.000000      7                     Fruits
# 1            390     0.150000      9                Ripe fruits
# 5            498     1.000000      9             Colored leaves
# 3            471     1.000000     10             Falling leaves
# 8            504     0.333333     10  Recent fruit or seed drop

# %%
ma[ma['kingdom'] == 'Plantae']
# Out:
#      species_id             common_name        genus  kingdom       species  \
# 0          1436              absinthium    Artemisia  Plantae    absinthium
# 2           174                 alfalfa     Medicago  Plantae        sativa
# 3          1174  Allegheny serviceberry  Amelanchier  Plantae        laevis
# 4          1446   alternateleaf dogwood       Cornus  Plantae  alternifolia
# 5            93       American basswood        Tilia  Plantae     americana
# ..          ...                     ...          ...      ...           ...
# 669           6   yellow marsh marigold       Caltha  Plantae     palustris
# 671         939        yellow pond-lily       Nuphar  Plantae         lutea
# 672         154     yellow star-thistle    Centaurea  Plantae  solstitialis
# 673         175      yellow sweetclover    Melilotus  Plantae   officinalis
# 674        1675          yellow thistle      Cirsium  Plantae    horridulum
#
#      itis_taxonomic_sn
# 0              35445.0
# 2             183623.0
# 3             182046.0
# 4              27813.0
# 5              21536.0
# ..                 ...
# 669            18454.0
# 671           503968.0
# 672            36972.0
# 673            26150.0
# 674            36379.0
#
# [461 rows x 6 columns]

# %%
dfs = []
for species_id in tqdm(ma[ma['kingdom'] == 'Plantae']['species_id'].unique()):
    species_id = int(species_id)
    try:
        df = build_pheno_summary(
            get_obs_df(datetime(2019, 1, 1), 12, species_id), 
            get_pheno_df(species_id)
        )
        df['species_id'] = species_id
        dfs.append(df)
    except:
        pass
df = pd.concat(dfs)
# Out:
# 100%|██████████| 461/461 [44:59<00:00,  5.85s/it]

# %%
df.to_csv('phenomes.csv', index=False)

# %%
df = pd.read_csv('phenomes.csv')
df = df[[c for c in df.columns if c != 'Unnamed: 0']]
df = df.merge(ma, on='species_id')
df
# Out:
#       phenophase_id  percent_yes  month            phenophase_name  \
# 0               482     1.000000      1             Initial growth
# 1               488     0.983333      7                     Leaves
# 2               501     0.518262      8               Open flowers
# 3               482     0.500000      4             Initial growth
# 4               488     1.000000      6                     Leaves
# ...             ...          ...    ...                        ...
# 2262            500     1.000000      6     Flowers or flower buds
# 2263            501     1.000000      6               Open flowers
# 2264            390     0.500000      7                Ripe fruits
# 2265            504     0.333333      7  Recent fruit or seed drop
# 2266            516     1.000000      7                     Fruits
#
#       species_id         common_name      genus  kingdom      species  \
# 0           1436          absinthium  Artemisia  Plantae   absinthium
# 1           1436          absinthium  Artemisia  Plantae   absinthium
# 2           1436          absinthium  Artemisia  Plantae   absinthium
# 3            174             alfalfa   Medicago  Plantae       sativa
# 4            174             alfalfa   Medicago  Plantae       sativa
# ...          ...                 ...        ...      ...          ...
# 2262         175  yellow sweetclover  Melilotus  Plantae  officinalis
# 2263         175  yellow sweetclover  Melilotus  Plantae  officinalis
# 2264         175  yellow sweetclover  Melilotus  Plantae  officinalis
# 2265         175  yellow sweetclover  Melilotus  Plantae  officinalis
# 2266         175  yellow sweetclover  Melilotus  Plantae  officinalis
#
#       itis_taxonomic_sn
# 0               35445.0
# 1               35445.0
# 2               35445.0
# 3              183623.0
# 4              183623.0
# ...                 ...
# 2262            26150.0
# 2263            26150.0
# 2264            26150.0
# 2265            26150.0
# 2266            26150.0
#
# [2267 rows x 10 columns]

# %%
with open('genuses.json', 'r') as fh:
    genuses = json.load(fh)

# %%
df['genus'] = df.apply(lambda r: r['genus'].lower(), axis=1)
fdf = df[df['genus'].isin(genuses)]
fdf
# Out:
#       phenophase_id  percent_yes  month            phenophase_name  \
# 9               371     0.633333      4         Breaking leaf buds
# 10              500     0.300000      4     Flowers or flower buds
# 11              467     0.750000      5       Increasing leaf size
# 12              483     1.000000      5                     Leaves
# 13              516     0.083333      6                     Fruits
# ...             ...          ...    ...                        ...
# 2239            498     0.981481      9             Colored leaves
# 2240            390     0.586905     10                Ripe fruits
# 2241            516     0.642857     10                     Fruits
# 2242            471     0.555556     12             Falling leaves
# 2243            504     0.555556     12  Recent fruit or seed drop
#
#       species_id             common_name        genus  kingdom  \
# 9           1174  Allegheny serviceberry  amelanchier  Plantae
# 10          1174  Allegheny serviceberry  amelanchier  Plantae
# 11          1174  Allegheny serviceberry  amelanchier  Plantae
# 12          1174  Allegheny serviceberry  amelanchier  Plantae
# 13          1174  Allegheny serviceberry  amelanchier  Plantae
# ...          ...                     ...          ...      ...
# 2239          97            yellow birch       betula  Plantae
# 2240          97            yellow birch       betula  Plantae
# 2241          97            yellow birch       betula  Plantae
# 2242          97            yellow birch       betula  Plantae
# 2243          97            yellow birch       betula  Plantae
#
#              species  itis_taxonomic_sn
# 9             laevis           182046.0
# 10            laevis           182046.0
# 11            laevis           182046.0
# 12            laevis           182046.0
# 13            laevis           182046.0
# ...              ...                ...
# 2239  alleghaniensis            19481.0
# 2240  alleghaniensis            19481.0
# 2241  alleghaniensis            19481.0
# 2242  alleghaniensis            19481.0
# 2243  alleghaniensis            19481.0
#
# [858 rows x 10 columns]

# %%
fdf[fdf['month'] == 3]
# Out:
#       phenophase_id  percent_yes  month         phenophase_name  species_id  \
# 53              500     0.805556      3  Flowers or flower buds        1048
# 331             490     1.000000      3            Pollen cones          48
# 1320            371     0.444444      3      Breaking leaf buds        1177
# 1545            371     0.340000      3      Breaking leaf buds        1755
# 1574            500     1.000000      3  Flowers or flower buds        1008
# 1630            371     1.000000      3      Breaking leaf buds         325
# 1647            393     0.500000      3         Ripe seed cones         968
# 1805            502     0.050000      3          Pollen release        1215
# 1852            371     1.000000      3      Breaking leaf buds        1753
# 1853            467     1.000000      3    Increasing leaf size        1753
# 1854            483     1.000000      3                  Leaves        1753
# 1950            371     0.356818      3      Breaking leaf buds          81
#
#             common_name        genus  kingdom      species  itis_taxonomic_sn
# 53         American elm        ulmus  Plantae    americana            19049.0
# 331        black spruce        picea  Plantae      mariana           183302.0
# 1320  mockernut hickory        carya  Plantae    tomentosa            19247.0
# 1545           post oak      quercus  Plantae     stellata            19422.0
# 1574       pussy willow        salix  Plantae     discolor            22524.0
# 1630     red elderberry     sambucus  Plantae     racemosa            35326.0
# 1647           red pine        pinus  Plantae     resinosa           183375.0
# 1805       Siberian elm        ulmus  Plantae       pumila            19057.0
# 1852        sour cherry       prunus  Plantae      cerasus            24773.0
# 1853        sour cherry       prunus  Plantae      cerasus            24773.0
# 1854        sour cherry       prunus  Plantae      cerasus            24773.0
# 1950           sweetgum  liquidambar  Plantae  styraciflua            19027.0

# %%
rows = [row for row in fdf[[
    'percent_yes', 'month', 'phenophase_name', 'common_name', 'genus', 'species'
]].rename({'percent_yes': 'score'}, axis=1).T.to_dict().values()]
with open('pheno_events.json', 'w') as fh:
    json.dump(rows, fh)
